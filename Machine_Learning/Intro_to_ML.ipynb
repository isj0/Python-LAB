# %%
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# #### MACHINE LEARNING FOUNDATIONS
#
# - Supervised Learning: For tasks with labelled data, desired output is known
# - UnSupervised Learning: For identifying patterns in unlabeled data without explicit guidance (only input, forms clusters)
# - Reinforcement Learning: Best for training agents to make decisions through interaction with an environment
#
# - Input (X) :- Independent variable, Output (y) :- Dependent variable ( what we want to predict)
#
# - MODEL :- Rule/pattern that will describe the relationship between input and output
#
# - TRAIN :- Feed the data and predict the model
#
# - TEST :-
#
# - DATA PRE-PROCESSING FUNNEL - RAW DATA to CLEANED DATA for ML MODEL Training
#     - Handle Missing Data
#     - Encode Categorical Values
#     - Feature Scaling
#     - Split Data
#     - Finally, you get Prepared Data

# %% [markdown]
# ##### DATA PRE-PROCESSING

# %%
data = {
    'Name': ['Pawan', 'Kapil', 'Lalit', 'Ishan', 'Om'],
    'Age': [25, None, 44, 23, None],
    'Salary': [50000, 60000, 70000, None, None]
}

df = pd.DataFrame(data)
print('Original DataFrame')
print(df)
print()
# print(df.isnull().sum())
# print()
# df_drop = df.dropna()
# print(df_drop)
# print()

# df['Age'].fillna(df['Age'].mean(), inplace=True)
# df['Salary'].fillna(df['Salary'].mean(), inplace=True)
# print(df)
# print()

print(df.isnull().mean() * 100)
# Out:
# Original DataFrame
#     Name   Age   Salary
# 0  Pawan  25.0  50000.0
# 1  Kapil   NaN  60000.0
# 2  Lalit  44.0  70000.0
# 3  Ishan  23.0      NaN
# 4     Om   NaN      NaN
#
# Name       0.0
# Age       40.0
# Salary    40.0
# dtype: float64

# %%
df = pd.read_csv("data.csv")

df_label = df.copy()

df_label

le = LabelEncoder()

df_label['Model_Encoded'] = le.fit_transform(df_label['Model'])

print("\nLabel Encoded Data")
print(df_label[["Car", "Model", "Volume", "Weight", "Model_Encoded"]].head())
# Out:
# Label Encoded Data
#           Car       Model  Volume  Weight  Model_Encoded
# 0      Toyoty        Aygo    1000     790             10
# 1  Mitsubishi  Space Star    1200    1160             29
# 2       Skoda      Citigo    1000     929             14
# 3        Fiat         500     900     865              4
# 4        Mini      Cooper    1500    1140             16

# %%
df_label.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car            36 non-null     object
#  1   Model          36 non-null     object
#  2   Volume         36 non-null     int64
#  3   Weight         36 non-null     int64
#  4   CO2            36 non-null     int64
#  5   Model_Encoded  36 non-null     int64
# dtypes: int64(4), object(2)
# memory usage: 1.8+ KB
